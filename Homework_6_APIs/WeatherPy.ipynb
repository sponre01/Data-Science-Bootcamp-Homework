# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Incorporated citipy to determine city based on latitude and longitude
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import datetime
import json

# Import API key
from api_keys import api_key 
from citipy import citipy
# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key + "&q="

#print(requests.get(url))
#response = requests.get(url).json()
#print(json.dumps(response, indent=4, sort_keys=True))

# %%
responses = []
city_dict = []

for city in cities:
    
    city_data = requests.get(url+city).json()
    responses.append(city_data)
    
    try:
        print(f"Processing City: {city_data['name']}")
        
        city_info = {'City Name': city_data['name'],
        'Country':city_data['sys']['country'],
        'Latitude':city_data['coord']['lat'],
        'Longitude':city_data['coord']['lon'], 
        'Temperature (F)':(city_data['main']['temp']),
        'Humidity (%)':(city_data['main']['humidity']),
        'Wind Speed (mph)':(city_data['wind']['speed']),
        'Cloud Cover (%)':(city_data['clouds']['all'])}
        city_dict.append(city_info)
        
    except:
        print(f"City {city} not found.")
        
city_df = pd.DataFrame(city_dict)
# Out:
# City attawapiskat not found.
# Processing City: Ivanjica
# Processing City: Tete
# Processing City: Danville
# Processing City: Rikitea
# City aflu not found.
# Processing City: Punta Arenas
# Processing City: Sioux Lookout
# Processing City: Cherskiy
# Processing City: Esperance
# Processing City: Iguape
# Processing City: Mataura
# Processing City: Piracuruca
# Processing City: Hilo
# Processing City: Qaanaaq
# Processing City: Mehamn
# Processing City: Cabo San Lucas
# Processing City: Camargo
# Processing City: Gizo
# Processing City: Bredasdorp
# Processing City: Lavrentiya
# Processing City: Ocampo
# City asau not found.
# Processing City: Kapaa
# Processing City: Ballina
# Processing City: Imbituba
# Processing City: Atuona
# Processing City: Jiangyou
# Processing City: Nikolskoye
# Processing City: Kavieng
# Processing City: Albany
# Processing City: Hermanus
# Processing City: Busselton
# Processing City: Hobart
# Processing City: Ushuaia
# Processing City: Temiscaming
# Processing City: East London
# Processing City: Tiksi
# Processing City: Jamestown
# Processing City: Tommot
# Processing City: Maryville
# Processing City: Dikson
# Processing City: Pucara
# Processing City: Bihariganj
# Processing City: Port Alfred
# Processing City: Hinatuan
# Processing City: Bluff
# Processing City: Zyryanka
# Processing City: Puerto Ayora
# City tsihombe not found.
# Processing City: Butaritari
# City taolanaro not found.
# City belushya guba not found.
# Processing City: Taoudenni
# Processing City: Bethel
# Processing City: Rawlins
# Processing City: Los Llanos de Aridane
# Processing City: Ilhabela
# Processing City: Mahon
# Processing City: Vaini
# Processing City: Lucapa
# Processing City: Tateyama
# Processing City: Constitucion
# Processing City: Quirinopolis
# Processing City: Suntar
# Processing City: Warmbad
# Processing City: Mar del Plata
# Processing City: Bemidji
# City sentyabrskiy not found.
# Processing City: Yellowknife
# Processing City: Preetz
# Processing City: Marsa Matruh
# Processing City: Hithadhoo
# Processing City: San Luis
# City urumqi not found.
# Processing City: Atambua
# Processing City: Waipawa
# City roches noires not found.
# Processing City: Pimenta Bueno
# City halalo not found.
# Processing City: Sistranda
# Processing City: Port Lincoln
# Processing City: Khatanga
# Processing City: Along
# Processing City: Boyuibe
# City barentsburg not found.
# City mys shmidta not found.
# Processing City: Longyearbyen
# Processing City: Barrow
# Processing City: Klaksvik
# Processing City: Avarua
# Processing City: San Patricio
# Processing City: Iqaluit
# Processing City: Oeiras
# Processing City: Haines Junction
# Processing City: Pevek
# Processing City: Kutum
# Processing City: Krasnoarmeysk
# Processing City: Lata
# Processing City: Shelburne
# Processing City: Moerai
# Processing City: Wajid
# Processing City: Scarborough
# Processing City: Nanortalik
# Processing City: Yar-Sale
# Processing City: Arraial do Cabo
# Processing City: Esso
# Processing City: Chuy
# Processing City: Husavik
# Processing City: Saskylakh
# City gazni not found.
# Processing City: Upernavik
# Processing City: Caravelas
# Processing City: Kodiak
# Processing City: Baculin
# Processing City: Kaitangata
# Processing City: Tuktoyaktuk
# City vaitupu not found.
# City bolsheustikinskoye not found.
# Processing City: Yakeshi
# Processing City: Qaqortoq
# Processing City: Rio Gallegos
# Processing City: Erkelenz
# Processing City: Shitanjing
# Processing City: Ilulissat
# Processing City: Verkhnyaya Inta
# Processing City: Faanui
# Processing City: Bandarbeyla
# Processing City: Sarka Ghat
# Processing City: Hay River
# Processing City: Broken Hill
# Processing City: Carnarvon
# Processing City: Lompoc
# Processing City: Simplicio Mendes
# Processing City: Tres Arroyos
# Processing City: Port Elizabeth
# City kashi not found.
# Processing City: Coruripe
# Processing City: Jumla
# Processing City: Guarapari
# Processing City: Hasaki
# Processing City: Luderitz
# City olafsvik not found.
# Processing City: Sisimiut
# Processing City: The Valley
# Processing City: Vypolzovo
# Processing City: Torbay
# Processing City: Komatipoort
# Processing City: Diffa
# Processing City: Cape Town
# Processing City: Kirakira
# City saleaula not found.
# Processing City: Oranjemund
# Processing City: Eyl
# Processing City: Shelekhov
# Processing City: Muisne
# Processing City: Havoysund
# Processing City: Chokurdakh
# Processing City: Ribeira Grande
# Processing City: Ngunguru
# Processing City: Victoria
# Processing City: Tasiilaq
# Processing City: Presidente Medici
# Processing City: Sao Filipe
# Processing City: Bella Vista
# City illoqqortoormiut not found.
# Processing City: Geraldton
# Processing City: Tautira
# Processing City: Cabrero
# Processing City: Castro
# Processing City: Akrolimni
# Processing City: Kununurra
# Processing City: Lembeni
# Processing City: Awbari
# Processing City: Saint George
# City naftah not found.
# City braslav not found.
# Processing City: Elk City
# Processing City: Puerto Colombia
# Processing City: Marsh Harbour
# Processing City: Greensburg
# Processing City: Port Hardy
# Processing City: Bedford
# Processing City: Kruisfontein
# Processing City: Vanavara
# Processing City: Ferrol
# City acarau not found.
# Processing City: Cidreira
# Processing City: Chivilcoy
# Processing City: Bambous Virieux
# Processing City: Yerbogachen
# Processing City: Ahipara
# City porto santo not found.
# Processing City: Vao
# Processing City: Lagoa
# Processing City: Thompson
# Processing City: Lethem
# Processing City: Oktyabrskiy
# Processing City: Sarangani
# Processing City: Loralai
# Processing City: Porosozero
# Processing City: Paris
# Processing City: Flinders
# City grand river south east not found.
# Processing City: Guerrero Negro
# Processing City: Ciudad Bolivar
# Processing City: Saint-Augustin
# Processing City: Patawag
# Processing City: Bathsheba
# Processing City: Saint-Francois
# Processing City: Coihaique
# Processing City: Songkhla
# Processing City: Wadi Maliz
# Processing City: Mantua
# Processing City: Seoul
# Processing City: Ponta do Sol
# Processing City: Erenhot
# Processing City: Onguday
# Processing City: Brigantine
# Processing City: New Norfolk
# Processing City: Buraydah
# Processing City: Mahebourg
# Processing City: Pangnirtung
# Processing City: Antipovka
# Processing City: Zaoyang
# Processing City: Kuytun
# Processing City: Hambantota
# Processing City: Gao
# Processing City: Aklavik
# Processing City: Chapais
# Processing City: Novovasylivka
# City falealupo not found.
# Processing City: Cap Malheureux
# Processing City: Ulladulla
# City samusu not found.
# Processing City: Aden
# Processing City: Port Keats
# Processing City: Weihai
# Processing City: Maniitsoq
# Processing City: Walvis Bay
# Processing City: Rawson
# Processing City: Purificacion
# Processing City: Namatanai
# Processing City: Yulara
# City amderma not found.
# Processing City: Cobija
# Processing City: Lander
# Processing City: Zalari
# City palabuhanratu not found.
# Processing City: Dicabisagan
# Processing City: Santa Rosa
# Processing City: Mount Isa
# Processing City: Ossora
# City tumannyy not found.
# Processing City: Edeia
# Processing City: Broome
# Processing City: Chicama
# City bokspits not found.
# Processing City: Hualmay
# Processing City: Vila Franca do Campo
# Processing City: Mudu
# Processing City: Berlevag
# Processing City: Goundam
# Processing City: Luba
# Processing City: Pangody
# Processing City: Aquiraz
# Processing City: Yingkou
# Processing City: Camacha
# Processing City: Mineral Wells
# Processing City: Saint-Georges
# Processing City: Saint-Philippe
# Processing City: Batagay
# Processing City: Mao
# Processing City: Poum
# Processing City: Saldanha
# Processing City: Yanam
# Processing City: Conakry
# Processing City: Port Blair
# Processing City: Narsaq
# Processing City: Arlit
# Processing City: Sur
# Processing City: Perth
# Processing City: Alexandria
# Processing City: Arman
# Processing City: Nexo
# Processing City: Tiznit
# Processing City: Provideniya
# City opobo not found.
# Processing City: Vila Velha
# Processing City: Najran
# City dolbeau not found.
# Processing City: Sehore
# City viligili not found.
# Processing City: Severo-Kurilsk
# Processing City: Dunedin
# Processing City: Kilindoni
# Processing City: Gat
# Processing City: Bacolod
# Processing City: Havre-Saint-Pierre
# Processing City: Pathein
# Processing City: Rovira
# Processing City: Nichinan
# Processing City: Georgetown
# Processing City: Itarema
# Processing City: Margate
# City bolungarvik not found.
# Processing City: Mosterhamn
# Processing City: Dubbo
# City kazalinsk not found.
# City louisbourg not found.
# Processing City: Sorland
# Processing City: De-Kastri
# Processing City: Fortuna
# Processing City: Kavaratti
# Processing City: Hovd
# Processing City: Letlhakeng
# Processing City: Touros
# Processing City: Fond du Lac
# Processing City: Puerto Leguizamo
# Processing City: Wattegama
# Processing City: Cravo Norte
# Processing City: Andilamena
# Processing City: La Ronge
# Processing City: Clyde River
# Processing City: Marsabit
# Processing City: Makasar
# Processing City: Toledo
# Processing City: Inirida
# City beringovskiy not found.
# Processing City: San Quintin
# Processing City: Saint Augustine
# Processing City: Port Augusta
# Processing City: Naze
# Processing City: Cervo
# Processing City: Hernani
# Processing City: Port-Gentil
# Processing City: Pacific Grove
# Processing City: Kovdor
# Processing City: Mukhen
# Processing City: Muros
# Processing City: Hami
# Processing City: Moen
# Processing City: Exmouth
# Processing City: Muriti
# Processing City: Kewanee
# City nizhneyansk not found.
# Processing City: Chimbote
# Processing City: Puerto Suarez
# Processing City: Homa Bay
# Processing City: Souillac
# Processing City: Lorengau
# Processing City: Islampur
# Processing City: San Vicente
# Processing City: Lazurne
# Processing City: Tawang
# Processing City: Saint-Joseph
# Processing City: Ancud
# Processing City: Katsuura
# Processing City: San Angelo
# Processing City: Oktyabrskoye
# City samalaeulu not found.
# Processing City: Cayenne
# Processing City: Skelleftea
# Processing City: Castelbuono
# City bengkulu not found.
# Processing City: Burgeo
# Processing City: Hutchinson
# Processing City: Mweka
# Processing City: Plettenberg Bay
# Processing City: Cabras
# Processing City: Karratha
# Processing City: Sitka
# Processing City: Mackenzie
# Processing City: Sabang
# Processing City: San Cristobal
# Processing City: Chapleau
# Processing City: Grand Gaube
# Processing City: Canico
# Processing City: Assiniboia
# Processing City: Natal
# Processing City: Salalah
# Processing City: Jiuquan
# Processing City: Blackfoot
# Processing City: Beipiao
# Processing City: Tocopilla
# Processing City: Benjamin Constant
# Processing City: Idah
# Processing City: Mareeba
# Processing City: Leibnitz
# Processing City: Valparaiso
# Processing City: Emerald
# Processing City: Samana
# Processing City: Changde
# Processing City: Rincon
# Processing City: Banda Aceh
# Processing City: Avera
# Processing City: Kisangani
# Processing City: Batticaloa
# Processing City: Borogontsy
# Processing City: Carlsbad
# Processing City: Kalmunai
# Processing City: Airai
# Processing City: Moron
# Processing City: Komsomolskiy
# Processing City: Yakima
# Processing City: Zambezi
# Processing City: Amnat Charoen
# Processing City: Baghdad
# City domoni not found.
# Processing City: Bonthe
# Processing City: Jatai
# Processing City: Bara
# City linchuan not found.
# Processing City: Tefe
# Processing City: Khasan
# Processing City: Grindavik
# Processing City: Bar Harbor
# Processing City: Sayla
# Processing City: Srandakan
# Processing City: Sumbe
# Processing City: Mandalgovi
# Processing City: Baoning
# Processing City: ChengDe
# Processing City: Bolshaya Martynovka
# Processing City: Grenada
# Processing City: Novoagansk
# Processing City: Lebu
# Processing City: Norman Wells
# Processing City: Maumelle
# Processing City: Russell
# Processing City: Lasa
# Processing City: Moranbah
# Processing City: Tarakan
# Processing City: Council Bluffs
# Processing City: Hamilton
# Processing City: Vitoria
# Processing City: Butte
# Processing City: Te Anau
# Processing City: Khandyga
# Processing City: Herat
# Processing City: Maraa
# Processing City: Buritis
# Processing City: Vestmannaeyjar
# Processing City: Kyshtovka
# Processing City: Tuatapere
# Processing City: Colares
# Processing City: Bratsk
# Processing City: Bereda
# Processing City: Mikun
# Processing City: Santa Cruz
# Processing City: Nome
# Processing City: Porto Novo
# City pemangkat not found.
# City rungata not found.
# Processing City: Buritizeiro
# Processing City: Bilgoraj
# Processing City: Tual
# Processing City: Mananjary
# Processing City: Paro
# Processing City: Zheleznodorozhnyy
# Processing City: Hervey Bay
# Processing City: Portland
# City jinchengjiang not found.
# Processing City: Ankpa
# Processing City: Alugan
# Processing City: Seydi
# Processing City: Tambovka
# Processing City: Komsomolets
# Processing City: Longyan
# Processing City: Loma Bonita
# Processing City: Sept-Iles
# Processing City: Wasilla
# Processing City: Liverpool
# City marcona not found.
# Processing City: Altay
# Processing City: Alofi
# Processing City: Eureka
# Processing City: Alice Springs
# Processing City: Ostersund
# Processing City: Magnitogorsk
# Processing City: Talnakh
# Processing City: Xiongzhou
# Processing City: Asuncion Nochixtlan
# Processing City: Ola
# Processing City: Chumphon
# Processing City: Leshukonskoye
# Processing City: Tucumcari
# Processing City: Victoria
# City kismayo not found.
# Processing City: Kiunga
# Processing City: Tank
# Processing City: Sechura
# Processing City: Inuvik
# Processing City: Sohagpur
# Processing City: Notodden
# Processing City: Novyy Urengoy
# Processing City: Tacuarembo
# Processing City: Poyarkovo
# Processing City: Dukat
# Processing City: Harbour Breton
# Processing City: Bramsche
# Processing City: Izhmorskiy
# Processing City: Goderich
# Processing City: Jacmel
# Processing City: Praxedis Guerrero
# City santa eulalia del rio not found.
# City skagastrond not found.
# Processing City: Chandbali
# Processing City: Zhigansk
# Processing City: Fort-Shevchenko
# Processing City: White Oak
# Processing City: Ostrovnoy
# Processing City: Delaware
# Processing City: Bizhbulyak
# Processing City: Pandan
# Processing City: San Antonio
# Processing City: Fare
# Processing City: Adet
# City tabiauea not found.
# City korla not found.
# Processing City: Sambava
# Processing City: Entre Rios
# Processing City: Ponta Delgada
# Processing City: Samarai
# City kuche not found.
# Processing City: Cochrane
# Processing City: Ottappalam
# Processing City: Sarahan
# Processing City: Palmdale
# Processing City: Moscow
# Processing City: Trairi
# Processing City: Madimba
# Processing City: Sharjah
# Processing City: Jijiga
# Processing City: Chifeng
# Processing City: Nelson Bay
# Processing City: Pontian Kecil
# Processing City: Windsor
# Processing City: Canutama
# Processing City: Innisfail
# Processing City: Mogadishu
# Processing City: Trincomalee
# Processing City: La Rioja
# Processing City: Santa Isabel
# Processing City: Floriano
# Processing City: Ambilobe
# Processing City: Friedberg
# Processing City: Luanda
# Processing City: Tilichiki
# Processing City: Acapulco
# City tunduru not found.
# Processing City: San Pedro del Pinatar
# Processing City: Humaita
# Processing City: Enshi
# Processing City: Surat Thani
# Processing City: Coquimbo
# City qafsah not found.
# Processing City: Marawi
# Processing City: Saint-Paul
# Processing City: Vostok
# Processing City: Cockburn Town
# Processing City: Kapuskasing
# Processing City: Lagos
# Processing City: Ribeira Brava
# Processing City: Huarmey
# Processing City: Onokhoy
# Processing City: Fagersta
# Processing City: Fukue
# Processing City: Miyang
# Processing City: Keetmanshoop
# Processing City: Laguna
# Processing City: Freeport
# Processing City: Kodinsk
# Processing City: Lubaczow
# Processing City: Vengerovo
# Processing City: Nueva Loja
# Processing City: Algeciras
# Processing City: Veraval
# Processing City: Inhambane
# Processing City: Palmer
# Processing City: Ayan
# Processing City: Iracoubo
# Processing City: Robertsport
# Processing City: Sangar
# Processing City: Hofn
# Processing City: Paulista
# Processing City: Bodden Town
# Processing City: San Ciro de Acosta
# City tambul not found.
# Processing City: Nandyal
# City khonuu not found.
# Processing City: Gohpur
# City karakendzha not found.
# Processing City: Leningradskiy
# Processing City: Wilmington
# Processing City: Rabo de Peixe
# Processing City: Vigrestad
# City tingrela not found.
# Processing City: Eregli
# City paradwip not found.
# Processing City: Faya
# Processing City: Mocuba

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv("city_data.csv", encoding="utf-8", index=False)

# %%
city_df
# Out:
#               City Name  Cloud Cover (%) Country  Humidity (%)  Latitude  \
# 0              Ivanjica               75      RS            85     43.58
# 1                  Tete               75      MZ            83    -16.16
# 2              Danville               90      US            96     36.59
# 3               Rikitea              100      PF           100    -23.12
# 4          Punta Arenas               40      CL            88    -53.16
# 5         Sioux Lookout               40      CA            86     50.10
# 6              Cherskiy               56      RU            33     68.75
# 7             Esperance               20      TT            51     10.24
# 8                Iguape               76      BR            91    -24.70
# 9               Mataura               56      NZ            58    -46.19
# 10           Piracuruca               56      BR            67     -3.93
# 11                 Hilo               75      US            93     19.71
# 12              Qaanaaq                8      GL            75     77.48
# 13               Mehamn               75      NO            92     71.03
# 14       Cabo San Lucas               75      MX            68     22.89
# 15              Camargo                0      MX            26     27.69
# 16                 Gizo                0      IL            66     31.80
# 17           Bredasdorp               24      ZA            60    -34.53
# 18           Lavrentiya               80      RU           100     65.58
# 19               Ocampo               92      PH            86     13.56
# 20                Kapaa               75      US            71     22.08
# 21              Ballina               90      IE            93     54.11
# 22             Imbituba               75      BR            78    -28.24
# 23               Atuona               64      PF           100     -9.80
# 24             Jiangyou               76      CN            87     31.78
# 25           Nikolskoye               90      RU            92     59.70
# 26              Kavieng               36      PG           100     -2.57
# 27               Albany               75      US            59     42.65
# 28             Hermanus                8      ZA            71    -34.42
# 29            Busselton                0      AU           100    -33.64
# ..                  ...              ...     ...           ...       ...
# 513               Fukue               75      JP           100     35.03
# 514              Miyang                0      CN            79     24.40
# 515        Keetmanshoop                0      NA            11    -26.57
# 516              Laguna                5      MX            29     27.52
# 517            Freeport               75      BS            78     26.54
# 518             Kodinsk               36      RU            26     58.60
# 519            Lubaczow               80      PL            87     50.16
# 520           Vengerovo               76      RU            81     55.68
# 521          Nueva Loja               40      EC            70      0.08
# 522           Algeciras               20      ES            62     36.13
# 523             Veraval               90      FR            86     49.65
# 524           Inhambane               40      MZ            88    -23.87
# 525              Palmer               75      AU            55    -34.85
# 526                Ayan                0      TR            75     40.67
# 527            Iracoubo               92      GF            84      5.48
# 528         Robertsport                0      LR            97      6.75
# 529              Sangar                0      RU             0     63.92
# 530                Hofn               75      IS            93     64.25
# 531            Paulista               44      BR            39     -6.60
# 532         Bodden Town               20      KY            79     19.28
# 533  San Ciro de Acosta               64      MX            77     21.65
# 534             Nandyal                0      IN            81     15.47
# 535              Gohpur                0      IN            83     26.89
# 536       Leningradskiy               32      RU           100     69.38
# 537          Wilmington                1      US            73     39.75
# 538       Rabo de Peixe               40      PT            93     37.80
# 539           Vigrestad               90      NO           100     58.57
# 540              Eregli               36      TR            89     37.51
# 541                Faya                0      SA            31     18.39
# 542              Mocuba               64      MZ            75    -16.84
#
#      Longitude  Temperature (F)  Wind Speed (mph)
# 0        20.23            20.10              5.82
# 1        33.59            77.00              4.70
# 2       -79.40            44.26              4.70
# 3      -134.97            76.98             20.29
# 4       -70.91            53.60             35.57
# 5       -91.92            29.21              6.93
# 6       161.30           -22.30              3.51
# 7       -61.45            86.00             18.34
# 8       -47.56            82.42              6.64
# 9       168.86            60.42             12.80
# 10      -41.72            86.16              3.96
# 11     -155.08            68.00              3.36
# 12      -69.36            -4.07              8.43
# 13       27.85            32.14              2.24
# 14     -109.91            67.05              3.36
# 15     -105.17            53.58              4.18
# 16       34.94            56.34              3.36
# 17       20.04            75.20             18.34
# 18     -170.99             9.43             15.82
# 19      123.37            78.78             14.25
# 20     -159.32            70.16             14.99
# 21       -9.15            41.29              5.82
# 22      -48.67            77.00             12.75
# 23     -139.03            80.22             16.49
# 24      104.73            29.95              2.73
# 25       30.79            21.20              6.71
# 26      150.80            83.05             13.47
# 27      -73.75            37.94             11.41
# 28       19.24            67.30              3.40
# 29      115.35            59.43              8.88
# ..         ...              ...               ...
# 513     136.69            44.60              3.36
# 514     103.44            42.33              6.20
# 515      18.15            98.60             16.11
# 516    -110.01            62.60              3.40
# 517     -78.70            78.80             11.41
# 518      99.18           -18.20              2.62
# 519      23.12            21.00             10.67
# 520      76.74             4.12              9.78
# 521     -76.88            82.15              2.24
# 522      -5.45            59.00             17.22
# 523       0.71            39.79              3.36
# 524      35.38            78.80              4.70
# 525     139.16            64.40              9.17
# 526      33.60            12.13              2.06
# 527     -53.21            79.59              6.20
# 528     -11.37            85.08              7.76
# 529     127.47           -35.12              0.72
# 530     -15.21            46.40              8.05
# 531     -37.62            91.87              6.20
# 532     -81.25            84.20             14.99
# 533     -99.82            58.89              2.17
# 534      78.48            59.47              3.62
# 535      93.63            42.60              2.84
# 536     178.42           -13.43             11.79
# 537     -75.55            41.59              8.05
# 538     -25.58            62.60              5.82
# 539       5.70            46.40             20.80
# 540      34.05            31.93              2.06
# 541      42.45            65.32              4.70
# 542      36.99            82.42              4.41
#
# [543 rows x 8 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#City Latitude vs. Max Temperature
plt.scatter(city_df['Latitude'], city_df['Temperature (F)'], alpha=0.5, edgecolor ='black', color="blue")

#Chart elements
plt.title(f"City Latitude vs. Max Temperature {datetime.datetime.today().strftime('%Y-%m-%d')}")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(True)

#Save and print
plt.savefig("City Latitude vs. Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#City Latitude vs. Max Temperature
plt.scatter(city_df['Latitude'], city_df['Humidity (%)'], alpha=0.5, edgecolor ='black', color="blue")

#Chart elements
plt.title(f"City Latitude vs. Humidity {datetime.datetime.today().strftime('%Y-%m-%d')}")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

#Save and print
plt.savefig("City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#City Latitude vs. Max Temperature
plt.scatter(city_df['Latitude'], city_df['Cloud Cover (%)'], alpha=0.5, edgecolor ='black', color="blue")

#Chart elements
plt.title(f"City Latitude vs. Cloudiness {datetime.datetime.today().strftime('%Y-%m-%d')}")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

#Save and print
plt.savefig("City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#City Latitude vs. Max Temperature
plt.scatter(city_df['Latitude'], city_df['Wind Speed (mph)'], alpha=0.5, edgecolor ='black', color="blue")

#Chart elements
plt.title(f"City Latitude vs. Wind Speed {datetime.datetime.today().strftime('%Y-%m-%d')}")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

#Save and print
plt.savefig("City Latitude vs. Wind Speed.png")
plt.show()
